# %% [markdown]
# <a href="https://colab.research.google.com/github/09sravyareddy/NNDL-ICP8/blob/main/CNN_ICP8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.models import Sequential
from keras.preprocessing import image
from keras.layers import Activation,Dense,Dropout,Conv2D,Flatten,MaxPooling2D,BatchNormalization
from keras.datasets import cifar100
from keras import optimizers
from matplotlib import pyplot as plt

# %%
#generate cifar100 data
(x_train,y_train),(x_test,y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 3s 0us/step

# %%
#config parameters
num_classes = 100
input_shape = x_train.shape[1:4]
optimizer = optimizers.Adam(lr=0.001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
one_hot_y_train = keras.utils.to_categorical(y_train, num_classes=num_classes)
one_hot_y_test = keras.utils.to_categorical(y_test, num_classes=num_classes)

# %%
# check data
plt.imshow(x_train[1])
print(x_train[1].shape)
# Out:
# (32, 32, 3)

# %%
# build model(similar to VGG16, only change the input and output shape)
model = Sequential()
model.add(Conv2D(64,(3,3),activation='relu',input_shape=input_shape,padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(4096,activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (Batch  (None, 32, 32, 64)        256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_1 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Bat  (None, 16, 16, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  batch_normalization_4 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_6 (Bat  (None, 8, 8, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 512)         1180160
#
#  batch_normalization_7 (Bat  (None, 4, 4, 512)         2048
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  batch_normalization_8 (Bat  (None, 4, 4, 512)         2048
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 512)         2359808
#
#  batch_normalization_9 (Bat  (None, 4, 4, 512)         2048
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 512)         0
#
#  conv2d_10 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_10 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_11 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  conv2d_12 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_12 (Ba  (None, 2, 2, 512)         2048
#  tchNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 1, 1, 512)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 2048)              8390656
#
#  dense_2 (Dense)             (None, 1024)              2098176
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 100)               102500
#
#  activation (Activation)     (None, 100)               0
#
# =================================================================
# Total params: 27424164 (104.61 MB)
# Trainable params: 27415716 (104.58 MB)
# Non-trainable params: 8448 (33.00 KB)
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=one_hot_y_train, batch_size=128, epochs=30, validation_split=0.1)
# Out:
# Epoch 1/30
# 352/352 [==============================] - 47s 88ms/step - loss: 4.2764 - accuracy: 0.0397 - val_loss: 4.7306 - val_accuracy: 0.0348
# Epoch 2/30
# 352/352 [==============================] - 28s 81ms/step - loss: 3.9276 - accuracy: 0.0656 - val_loss: 4.8051 - val_accuracy: 0.0476
# Epoch 3/30
# 352/352 [==============================] - 30s 84ms/step - loss: 3.7085 - accuracy: 0.0925 - val_loss: 3.9138 - val_accuracy: 0.1050
# Epoch 4/30
# 352/352 [==============================] - 29s 83ms/step - loss: 3.4520 - accuracy: 0.1316 - val_loss: 3.3779 - val_accuracy: 0.1558
# Epoch 5/30
# 352/352 [==============================] - 29s 82ms/step - loss: 3.2011 - accuracy: 0.1785 - val_loss: 3.2389 - val_accuracy: 0.1918
# Epoch 6/30
# 352/352 [==============================] - 29s 82ms/step - loss: 2.9446 - accuracy: 0.2274 - val_loss: 2.9098 - val_accuracy: 0.2486
# Epoch 7/30
# 352/352 [==============================] - 29s 83ms/step - loss: 2.7457 - accuracy: 0.2662 - val_loss: 2.7727 - val_accuracy: 0.2702
# Epoch 8/30
# 352/352 [==============================] - 28s 81ms/step - loss: 2.5620 - accuracy: 0.3111 - val_loss: 2.6355 - val_accuracy: 0.3090
# Epoch 9/30
# 352/352 [==============================] - 28s 81ms/step - loss: 2.3918 - accuracy: 0.3457 - val_loss: 2.5728 - val_accuracy: 0.3398
# Epoch 10/30
# 352/352 [==============================] - 29s 81ms/step - loss: 2.2509 - accuracy: 0.3834 - val_loss: 2.6694 - val_accuracy: 0.3330
# Epoch 11/30
# 352/352 [==============================] - 29s 82ms/step - loss: 2.1033 - accuracy: 0.4172 - val_loss: 2.4028 - val_accuracy: 0.3852
# Epoch 12/30
# 352/352 [==============================] - 29s 83ms/step - loss: 1.9851 - accuracy: 0.4449 - val_loss: 2.2593 - val_accuracy: 0.4058
# Epoch 13/30
# 352/352 [==============================] - 29s 82ms/step - loss: 1.8709 - accuracy: 0.4750 - val_loss: 2.1830 - val_accuracy: 0.4242
# Epoch 14/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.7618 - accuracy: 0.5028 - val_loss: 2.1466 - val_accuracy: 0.4408
# Epoch 15/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.6663 - accuracy: 0.5324 - val_loss: 2.2219 - val_accuracy: 0.4418
# Epoch 16/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.5682 - accuracy: 0.5519 - val_loss: 2.1191 - val_accuracy: 0.4716
# Epoch 17/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.5032 - accuracy: 0.5723 - val_loss: 2.1252 - val_accuracy: 0.4754
# Epoch 18/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.3950 - accuracy: 0.5996 - val_loss: 2.1238 - val_accuracy: 0.4854
# Epoch 19/30
# 352/352 [==============================] - 29s 82ms/step - loss: 1.3362 - accuracy: 0.6172 - val_loss: 2.1091 - val_accuracy: 0.4804
# Epoch 20/30
# 352/352 [==============================] - 29s 82ms/step - loss: 1.2213 - accuracy: 0.6436 - val_loss: 2.0904 - val_accuracy: 0.5048
# Epoch 21/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.1593 - accuracy: 0.6634 - val_loss: 2.0269 - val_accuracy: 0.5066
# Epoch 22/30
# 352/352 [==============================] - 28s 81ms/step - loss: 1.0772 - accuracy: 0.6887 - val_loss: 2.1197 - val_accuracy: 0.5060
# Epoch 23/30
# 352/352 [==============================] - 29s 82ms/step - loss: 1.0672 - accuracy: 0.6918 - val_loss: 2.1322 - val_accuracy: 0.5178
# Epoch 24/30
# 352/352 [==============================] - 28s 81ms/step - loss: 0.9753 - accuracy: 0.7165 - val_loss: 2.1640 - val_accuracy: 0.5140
# Epoch 25/30
# 352/352 [==============================] - 29s 82ms/step - loss: 0.9228 - accuracy: 0.7298 - val_loss: 2.0914 - val_accuracy: 0.5268
# Epoch 26/30
# 352/352 [==============================] - 29s 82ms/step - loss: 0.8400 - accuracy: 0.7523 - val_loss: 2.2414 - val_accuracy: 0.5130
# Epoch 27/30
# 352/352 [==============================] - 29s 82ms/step - loss: 0.8287 - accuracy: 0.7557 - val_loss: 2.3456 - val_accuracy: 0.5108
# Epoch 28/30
# 352/352 [==============================] - 28s 81ms/step - loss: 0.7519 - accuracy: 0.7794 - val_loss: 2.2839 - val_accuracy: 0.5222
# Epoch 29/30
# 352/352 [==============================] - 28s 81ms/step - loss: 0.7115 - accuracy: 0.7894 - val_loss: 2.3604 - val_accuracy: 0.5046
# Epoch 30/30
# 352/352 [==============================] - 28s 81ms/step - loss: 0.6774 - accuracy: 0.7990 - val_loss: 2.4038 - val_accuracy: 0.5052

# %%
# evaluate
print(model.metrics_names)
model.evaluate(x=x_test,y=one_hot_y_test,batch_size=512)
# Out:
# ['loss', 'accuracy']
# 20/20 [==============================] - 7s 176ms/step - loss: 2.2925 - accuracy: 0.5229
# [2.292543888092041, 0.5228999853134155]

# %%
model.save("keras-VGG16-cifar10.h5")
plt.imshow(x_test[1000])

result = model.predict(x_test[1000:1001]).tolist()
predict = 0
expect = y_test[1000][0]
for i,_ in enumerate(result[0]):
   if result[0][i] > result[0][predict]:
    predict = i
print("predict class:",predict)
print("expected class:",expect)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1/1 [==============================] - 1s 1s/step
# predict class: 63
# expected class: 65

# %%
# save model
model.save("keras-VGG16-cifar10.h5")

# %%
#plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#plot the training and validation loss
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# calculate the confusion matrix
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = y_test.ravel()
cm = confusion_matrix(y_true, y_pred_classes)

# plot the confusion matrix
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion matrix')
plt.colorbar()
tick_marks = np.arange(num_classes)
plt.xticks(tick_marks, range(num_classes))
plt.yticks(tick_marks, range(num_classes))
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()

# plot a histogram of the predicted probabilities for a sample image
plt.hist(y_pred[1000])
plt.title('Predicted probabilities')
plt.xlabel('Probability')
plt.ylabel('Frequency')
plt.show()
# Out:
# 313/313 [==============================] - 3s 8ms/step
